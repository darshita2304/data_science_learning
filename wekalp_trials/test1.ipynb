# %%
import pandas as pd
import numpy as np
# Example DataFrame
df = pd.DataFrame({
    'A': [1, 'N/A', np.nan, 'NULL', 'nan'],
    'B': [np.nan, pd.NaT, '#N/A', 'foo', '1.#IND'],
    'C': [None, 'n/a', 'NaN', 'null', '1.#QNAN'],
    'D': ['#NA', None, '<NA>', pd.NaT, '2023-01-01']
})

# %%
df
# Out:
#       A       B        C           D
# 0     1     NaN     None         #NA
# 1   N/A     NaT      n/a        None
# 2   NaN    #N/A      NaN        <NA>
# 3  NULL     foo     null         NaT
# 4   nan  1.#IND  1.#QNAN  2023-01-01

# %%
df.fillna("")
# Out:
#       A       B        C           D
# 0     1                          #NA
# 1   N/A              n/a
# 2          #N/A      NaN        <NA>
# 3  NULL     foo     null
# 4   nan  1.#IND  1.#QNAN  2023-01-01

# %%
values_to_replace = ["", "#N/A", "#N/A N/A", "#NA", "-1.#IND", "-1.#QNAN", "-NaN", "-nan", 
                     "1.#IND", "1.#QNAN", "<NA>", "N/A", "NA", "NULL", "NaN", "None", 
                     "n/a", "nan", "null", np.nan, pd.NaT, None]

# Replace all specified values with an empty string
df.replace(values_to_replace, "")
# Out:
#    A    B C           D
# 0  1
# 1
# 2
# 3     foo
# 4            2023-01-01

# %%
df1 = pd.DataFrame({
    'A': [1, 'N/A', np.nan, 'NULL', 'nan'],
    'B': [np.nan, pd.NaT, '#N/A', 'foo', '1.#IND'],
    'C': [None, 'n/a', 'NaN', 'null', '1.#QNAN'],
    'D': ['#NA', None, '<NA>', pd.NaT, '2023-01-01']
})

# %%
df1.to_csv("1.csv")

# %%
ddf = pd.read_csv("1.csv")

# %%
ddf
# Out:
#    Unnamed: 0    A    B   C           D
# 0           0  1.0  NaN NaN         NaN
# 1           1  NaN  NaN NaN         NaN
# 2           2  NaN  NaN NaN         NaN
# 3           3  NaN  foo NaN         NaN
# 4           4  NaN  NaN NaN  2023-01-01

# %%
ddf = pd.read_table("1.csv")

# %%
ddf.fillna("")
# Out:
#                           ,A,B,C,D
# 0                        0,1,,,#NA
# 1                      1,N/A,,n/a,
# 2                 2,,#N/A,NaN,<NA>
# 3                 3,NULL,foo,null,
# 4  4,nan,1.#IND,1.#QNAN,2023-01-01

# %%
ddf
# Out:
#                           ,A,B,C,D
# 0                        0,1,,,#NA
# 1                      1,N/A,,n/a,
# 2                 2,,#N/A,NaN,<NA>
# 3                 3,NULL,foo,null,
# 4  4,nan,1.#IND,1.#QNAN,2023-01-01

# %%
ddf = pd.read_table("1.csv").to_pandas()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24464\2855721567.py in ?()
# ----> 1 ddf = pd.read_table("1.csv").to_pandas()
#
# f:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_pandas'

# %%
df1 = pd.read_csv("12.csv", dtype=str)

# %%
df1
# Out:
#    Currency Code      Rate
# 0            USD    82.725
# 1            GBP   99.5275
# 2            EUR    88.135
# 3            JPY    0.6262
# 4            CHF   89.5975
# 5            AUD     56.17
# 6            CAD   61.0525
# 7            SGD    61.655
# 8            SEK    7.9175
# 9            DKK   11.8525
# 10           NOK    8.3825
# 11           HKD    10.605
# 12           MYR     18.78
# 13           NZD    52.395
# 14           THB    2.3875
# 15           BHD  219.4025
# 16           AED    22.525
# 17           KES   0.67038
# 18           IDR   0.00533
# 19           QAR   22.6475
# 20           OMR   214.875
# 21           EGP    3.3425
# 22           SAR    21.995
# 23           KWD  270.2825
# 24           ZAR    4.8725
# 25           CNH   0.11913
# 26           INR         1
# 27           USD    82.725
# 28           GBP   99.5275
# 29           EUR    88.135
# 30           JPY    0.6262
# 31           CHF   89.5975
# 32           AUD     56.17
# ...

# %%
df1.fillna("")
# Out:
#    Currency Code      Rate
# 0            USD    82.725
# 1            GBP   99.5275
# 2            EUR    88.135
# 3            JPY    0.6262
# 4            CHF   89.5975
# 5            AUD     56.17
# 6            CAD   61.0525
# 7            SGD    61.655
# 8            SEK    7.9175
# 9            DKK   11.8525
# 10           NOK    8.3825
# 11           HKD    10.605
# 12           MYR     18.78
# 13           NZD    52.395
# 14           THB    2.3875
# 15           BHD  219.4025
# 16           AED    22.525
# 17           KES   0.67038
# 18           IDR   0.00533
# 19           QAR   22.6475
# 20           OMR   214.875
# 21           EGP    3.3425
# 22           SAR    21.995
# 23           KWD  270.2825
# 24           ZAR    4.8725
# 25           CNH   0.11913
# 26           INR         1
# 27           USD    82.725
# 28           GBP   99.5275
# 29           EUR    88.135
# 30           JPY    0.6262
# 31           CHF   89.5975
# 32           AUD     56.17
# ...

# %%
df1 = pd.read_csv("11.csv", dtype=str)

# %%
df1
# Out:
#    Currency Code      Rate
# 0            USD    82.725
# 1            GBP   99.5275
# 2            EUR    88.135
# 3            JPY    0.6262
# 4            CHF   89.5975
# 5            AUD     56.17
# 6            CAD   61.0525
# 7            SGD    61.655
# 8            SEK    7.9175
# 9            DKK   11.8525
# 10           NOK    8.3825
# 11           HKD    10.605
# 12           MYR     18.78
# 13           NZD    52.395
# 14           THB    2.3875
# 15           BHD  219.4025
# 16           AED    22.525
# 17           KES   0.67038
# 18           IDR   0.00533
# 19           QAR   22.6475
# 20           OMR   214.875
# 21           EGP    3.3425
# 22           SAR    21.995
# 23           KWD  270.2825
# 24           ZAR    4.8725
# 25           CNH   0.11913
# 26           INR         1
# 27           USD    82.725
# 28           GBP   99.5275
# 29           EUR    88.135
# 30           JPY    0.6262
# 31           CHF   89.5975
# 32           AUD     56.17
# ...

# %%
df1[(df1["Rate"] == "1")]
# Out:
#    Currency Code Rate
# 26           INR    1
# 53           INR    1

# %%
source_col_df
# Out:
# Empty DataFrame
# Columns: [Currency Code, Rate]
# Index: []

# %%
df1.fillna("")
# Out:
#    Currency Code      Rate
# 0            USD    82.725
# 1            GBP   99.5275
# 2            EUR    88.135
# 3            JPY    0.6262
# 4            CHF   89.5975
# 5            AUD     56.17
# 6            CAD   61.0525
# 7            SGD    61.655
# 8            SEK    7.9175
# 9            DKK   11.8525
# 10           NOK    8.3825
# 11           HKD    10.605
# 12           MYR     18.78
# 13           NZD    52.395
# 14           THB    2.3875
# 15           BHD  219.4025
# 16           AED    22.525
# 17           KES   0.67038
# 18           IDR   0.00533
# 19           QAR   22.6475
# 20           OMR   214.875
# 21           EGP    3.3425
# 22           SAR    21.995
# 23           KWD  270.2825
# 24           ZAR    4.8725
# 25           CNH   0.11913
# 26           INR         1
# 27           USD    82.725
# 28           GBP   99.5275
# 29           EUR    88.135
# 30           JPY    0.6262
# 31           CHF   89.5975
# 32           AUD     56.17
# ...

# %%
import pandas as pd
dd = pd.read_parquet('23.parquet', engine='pyarrow')

# %%
dd
# Out:
#    Currency Code      Rate
# 0            USD    82.725
# 1            GBP   99.5275
# 2            EUR    88.135
# 3            JPY    0.6262
# 4            CHF   89.5975
# 5            AUD     56.17
# 6            CAD   61.0525
# 7            SGD    61.655
# 8            SEK    7.9175
# 9            DKK   11.8525
# 10           NOK    8.3825
# 11           HKD    10.605
# 12           MYR     18.78
# 13           NZD    52.395
# 14           THB    2.3875
# 15           BHD  219.4025
# 16           AED    22.525
# 17           KES   0.67038
# 18           IDR   0.00533
# 19           QAR   22.6475
# 20           OMR   214.875
# 21           EGP    3.3425
# 22           SAR    21.995
# 23           KWD  270.2825
# 24           ZAR    4.8725
# 25           CNH   0.11913
# 26           INR         1
# 27           USD    82.725
# 28           GBP   99.5275
# 29           EUR    88.135
# 30           JPY    0.6262
# 31           CHF   89.5975
# 32           AUD     56.17
# ...

# %%
dd.fillna("")
# Out:
#    Currency Code      Rate
# 0            USD    82.725
# 1            GBP   99.5275
# 2            EUR    88.135
# 3            JPY    0.6262
# 4            CHF   89.5975
# 5            AUD     56.17
# 6            CAD   61.0525
# 7            SGD    61.655
# 8            SEK    7.9175
# 9            DKK   11.8525
# 10           NOK    8.3825
# 11           HKD    10.605
# 12           MYR     18.78
# 13           NZD    52.395
# 14           THB    2.3875
# 15           BHD  219.4025
# 16           AED    22.525
# 17           KES   0.67038
# 18           IDR   0.00533
# 19           QAR   22.6475
# 20           OMR   214.875
# 21           EGP    3.3425
# 22           SAR    21.995
# 23           KWD  270.2825
# 24           ZAR    4.8725
# 25           CNH   0.11913
# 26           INR         1
# 27           USD    82.725
# 28           GBP   99.5275
# 29           EUR    88.135
# 30           JPY    0.6262
# 31           CHF   89.5975
# 32           AUD     56.17
# ...

# %%
import datetime

# Example date
date = datetime.datetime(2024, 9, 3)

# Convert the date to a timestamp
timestamp = int(date.timestamp())

print("Timestamp as an integer:", timestamp)
# Out:
# Timestamp as an integer: 1725301800
