# %%
import pandas as pd

# %%
data = pd.read_csv("sample.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  India Id    Trade Id  \
# 0           0     26997  13782015.0
# 1           1     27966  14734932.0
# 2           2     33963  14459168.0
# 3           3     34740  14559806.0
# 4           4     34741  14559817.0
#
#                                  Product Description     Trade Date  \
# 0  2199667/FXFlexiForward/MerchantFX/RETAIL/USD/I...  01-03-21 0:00
# 1  2219298/FXFlexiForward/MerchantFX/RETAIL/USD/I...  12-03-21 0:00
# 2  2360870/FXFlexiForward/MerchantFX/RETAIL/USD/I...  10-06-21 0:00
# 3  2385501/FXFlexiForward/MerchantFX/RETAIL/USD/I...  25-06-21 0:00
# 4                                                NaN  25-06-21 0:00
#
#   Start Date MR_MATURITY_DATE   Entered Date CounterParty (F)  \
# 0   01-09-21         07-03-24  01-03-21 0:00   Counterparty 1
# 1   30-07-21         23-03-25  12-03-21 0:00   Counterparty 2
# 2   14-12-21         22-09-24  10-06-21 0:00   Counterparty 3
# 3   30-09-21         30-06-24  25-06-21 0:00   Counterparty 4
# ...

# %%
n = len(data)

# %%
empty_list = [None] * n
print(empty_list)  # Output: [None, None, None, None, None]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
print(empty_list[5])
# Out:
# None

# %%
empty_list[5] = "test"

# %%
empty_list1 = [None] * n
print(empty_list1)  # Output: [None, None, None, None, None]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
data.insert(2, "Age", empty_list, True)

# %%
empty_list1[5] = "1"

# %%
data.insert(2, "Age1", empty_list1, True)

# %%
data["new"] = data["Age"] + data["Age1"]

# %%
lst = data["new"].to_numpy()

# %%
new_col = [None] * n

# %%
import numpy as np

# %%
# Replace values containing the substring 'apple'
np_array = np.array([('orange' if isinstance(x, str) and 'test' in x else x) for x in lst])

# %%
np_array
# Out:
# array(['nan', 'nan', 'nan', 'nan', 'nan', 'orange', 'nan', 'nan', 'nan',
#        'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan',
#        'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'],
#       dtype='<U32')

# %%
data.head(6)
# Out:
#    Unnamed: 0  India Id  Age1   Age    Trade Id  \
# 0           0     26997  None  None  13782015.0
# 1           1     27966  None  None  14734932.0
# 2           2     33963  None  None  14459168.0
# 3           3     34740  None  None  14559806.0
# 4           4     34741  None  None  14559817.0
# 5           5     35314     1  test  14588875.0
#
#                                  Product Description     Trade Date  \
# 0  2199667/FXFlexiForward/MerchantFX/RETAIL/USD/I...  01-03-21 0:00
# 1  2219298/FXFlexiForward/MerchantFX/RETAIL/USD/I...  12-03-21 0:00
# 2  2360870/FXFlexiForward/MerchantFX/RETAIL/USD/I...  10-06-21 0:00
# 3  2385501/FXFlexiForward/MerchantFX/RETAIL/USD/I...  25-06-21 0:00
# 4                                                NaN  25-06-21 0:00
# 5  2393387/FXFlexiForward/MerchantFX/RETAIL/USD/I...  30-06-21 0:00
#
#   Start Date MR_MATURITY_DATE   Entered Date  ... Currency Pair Prim Cur  \
# ...
