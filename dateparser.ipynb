# %%
import datetime


def dateparse(x): return datetime.datetime.strptime(x, "%d%b%Y").strftime('%Y-%m-%d')


df = pd.read_csv("stock_data.csv", parse_dates=['expiry'], date_parser=dateparse)

# %%
import datetime

date_str = "25OCT2022"

# Parse the date string into a datetime object
date_obj = datetime.datetime.strptime(date_str, '%d%b%Y')

# Format the datetime object into a string
formatted_date_str = date_obj.strftime('%Y-%m-%d')

# Print the formatted date string
print(formatted_date_str)
# Out:
# 2022-10-25

# %%
df
# Out:
#                      symbol  token        name     expiry     strike  lotsize  \
# 0   MIDCPNIFTY25OCT227100PE  56382  MIDCPNIFTY 2022-10-25   710000.0     75.0
# 1   BANKNIFTY01SEP2233200CE  51471   BANKNIFTY 2022-09-01  3320000.0     25.0
# 2   BANKNIFTY08SEP2236600PE  46223   BANKNIFTY 2022-09-08  3660000.0     25.0
# 3   BANKNIFTY18AUG2235400CE  47420   BANKNIFTY 2022-08-18  3540000.0     25.0
# 4    FINNIFTY30AUG2215100PE  38945    FINNIFTY 2022-08-30  1510000.0     40.0
# 5       NIFTY01SEP2219200CE  40550       NIFTY 2022-09-01  1920000.0     50.0
# 6    FINNIFTY20SEP2218500CE  49458    FINNIFTY 2022-09-20  1850000.0     40.0
# 7       NIFTY27JUN2418000CE  55115       NIFTY 2024-06-27  1800000.0     50.0
# 8    FINNIFTY20SEP2215000PE  49227    FINNIFTY 2022-09-20  1500000.0     40.0
# 9       NIFTY29DEC2213100PE  42707       NIFTY 2022-12-29  1310000.0     50.0
# 10  BANKNIFTY15SEP2236300CE  51580   BANKNIFTY 2022-09-15  3630000.0     25.0
# 11  MIDCPNIFTY04OCT226900PE  43544  MIDCPNIFTY 2022-10-04   690000.0      NaN
# 12  BANKNIFTY18AUG2232900CE  47259   BANKNIFTY 2022-08-18  3290000.0     25.0
# 13  BANKNIFTY27OCT2236000CE  57085   BANKNIFTY 2022-10-27  3600000.0     25.0
# 14      NIFTY15SEP2215950PE    NAN       NIFTY 2022-09-15  1595000.0      NaN
# 15      NIFTY22SEP2217750PE  52697       NIFTY 2022-09-22  1775000.0     50.0
# 16  BANKNIFTY25AUG2240000PE  56041   BANKNIFTY 2022-08-25  4000000.0     25.0
# 17  MIDCPNIFTY04OCT228200CE  43740  MIDCPNIFTY 2022-10-04   820000.0     75.0
#
#    instrumenttype exch_seg  tick_size
# 0          OPTIDX      NFO        5.0
# 1          OPTIDX      NFO        5.0
# 2          OPTIDX      NFO        5.0
# 3          OPTIDX      NFO        5.0
# 4          OPTIDX      NFO        5.0
# 5          OPTIDX      NFO        5.0
# 6          OPTIDX      NFO        5.0
# 7          OPTIDX      NFO        5.0
# 8          OPTIDX      NaN        5.0
# 9          OPTIDX      NFO        5.0
# 10         OPTIDX      NFO        5.0
# 11         OPTIDX      NFO        5.0
# 12         OPTIDX      NFO        5.0
# 13         OPTIDX      NFO        5.0
# 14         OPTIDX      NFO        5.0
# 15         OPTIDX      NFO        5.0
# 16         OPTIDX      NFO        5.0
# 17         OPTIDX      NFO        5.0
